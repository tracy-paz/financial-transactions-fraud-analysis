# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import psycopg2 as psy
import getpass

# %%
pw = getpass.getpass("Postgres password: ")
# Out:
# Postgres password:  ········

# %%
conn = psy.connect(database='fraud_db', user="postgres", host='localhost', password=pw)

# %%
pd.read_sql_query('SELECT 1', conn)
# Out:
# /var/folders/mc/8qjcwqc57xsd50_zblgvcrx40000gn/T/ipykernel_28779/3740269036.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('SELECT 1', conn)
#    ?column?
# 0         1

# %%
df_amount_bins = pd.read_sql_query('SELECT * FROM v_fraud_amount_bins;', conn)
# Out:
# /var/folders/mc/8qjcwqc57xsd50_zblgvcrx40000gn/T/ipykernel_28779/1116093810.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_amount_bins = pd.read_sql_query('SELECT * FROM v_fraud_amount_bins;', conn)

# %%
df_amount_bins.head()
# Out:
#    transactions   amount_bin  fraud_tx  fraud_pct
# 0       2397713      A. <$10      2620       0.11
# 1       3537973   B. $10-$50      2813       0.08
# 2       2765384  C. $50-$200      5705       0.21
# 3        213893     D. >$200      2194       1.03

# %%
df_errors = pd.read_sql_query('SELECT * FROM v_fraud_errors_rate_labled;', conn)
# Out:
# /var/folders/mc/8qjcwqc57xsd50_zblgvcrx40000gn/T/ipykernel_28779/3793464914.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_errors = pd.read_sql_query('SELECT * FROM v_fraud_errors_rate_labled;', conn)

# %%
df_errors.head()
# Out:
#              error_type  transactions  fraud_tx  fraud_pct
# 0  Insufficient Balance         88175       173       0.20
# 1               Bad PIN         21730       113       0.52
# 2      Technical Glitch         18013        32       0.18
# 3       Bad Card Number          5350        60       1.12
# 4               Bad CVV          4183       142       3.39

# %%
df_fraud_rate_tx = pd.read_sql_query('SELECT * FROM v_fraud_rate_by_transaction_method;', conn)
# Out:
# /var/folders/mc/8qjcwqc57xsd50_zblgvcrx40000gn/T/ipykernel_28779/645246334.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_fraud_rate_tx = pd.read_sql_query('SELECT * FROM v_fraud_rate_by_transaction_method;', conn)

# %%
df_fraud_rate_tx.head()
# Out:
#    transaction_method  labeled_tx  fraud_tx  fraud_rate_pct
# 0    Chip Transaction     3202776      3176            0.10
# 1  Online Transaction     1043975      8779            0.84
# 2   Swipe Transaction     4668212      1377            0.03

# %%
df_raw_fraud_rate = pd.read_sql_query('SELECT * FROM v_mcc_fraud_rate_raw;', conn)
# Out:
# /var/folders/mc/8qjcwqc57xsd50_zblgvcrx40000gn/T/ipykernel_28779/1873218210.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_raw_fraud_rate = pd.read_sql_query('SELECT * FROM v_mcc_fraud_rate_raw;', conn)

# %%
df_raw_fraud_rate.head()
# Out:
#     mcc                                  mcc_description  labeled_tx  \
# 0  1711  Heating, Plumbing, Air Conditioning Contractors        2101
# 1  3000                                       Steelworks        2039
# 2  3001                     Steel Products Manufacturing        2062
# 3  3005                  Miscellaneous Metal Fabrication         256
# 4  3006          Miscellaneous Fabricated Metal Products         245
#
#    fraud_tx  fraud_rate_pct
# 0         0            0.00
# 1        37            1.81
# 2        25            1.21
# 3        22            8.59
# 4        29           11.84
